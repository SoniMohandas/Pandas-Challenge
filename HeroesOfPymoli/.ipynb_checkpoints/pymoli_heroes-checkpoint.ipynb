# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
from IPython.display import display

# %%
# Specifying file path
file_path="Resources/purchase_data.csv"

# %%
# Read purchase_data file and stores into pandas data frame
purchase_read=pd.read_csv(file_path, delimiter=',')

# Copy of dataframe created to keep the original in its own
players_df = purchase_read.copy()
gender_df= purchase_read.copy()
players_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
# Unique value of SN gives total number of players
uniq_players=len(players_df["SN"].unique())

# Display of total number of players in a data frame
total_players=pd.DataFrame({"Total Players":[uniq_players]})
total_players
# Out:
#    Total Players
# 0            576

# %%
# Length of series of Item Id unique value is equal to number of unique items
uniq_items=len(players_df["Item ID"].unique())

# Calculating average of Price
avg_price=round(players_df["Price"].mean(),2)

# Counting purchase id gives total purchase
total_purchase=players_df["Purchase ID"].count()

# Sum of Price series gives total revenue
total_revenue=players_df["Price"].sum()

# Dataframe created for the disired output
purchase_analysis=pd.DataFrame({"Number of Unique Items":[uniq_items],
                                "Average Price":[avg_price],"Total Purchase":[total_purchase],
                                "Total Revenue":[total_revenue]})

# Style formatting the dataframe
purchase_analysis.style.format({'Average Price': "${0:.2f}", "Total Revenue":"${0:.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_3fa107c6_d8ef_11eb_b589_646c80b0af54" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Unique Items</th>        <th class="col_heading level0 col1" >Average Price</th>        <th class="col_heading level0 col2" >Total Purchase</th>        <th class="col_heading level0 col3" >Total Revenue</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3fa107c6_d8ef_11eb_b589_646c80b0af54level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3fa107c6_d8ef_11eb_b589_646c80b0af54row0_col0" class="data row0 col0" >179</td>
#                         <td id="T_3fa107c6_d8ef_11eb_b589_646c80b0af54row0_col1" class="data row0 col1" >$3.05</td>
#                         <td id="T_3fa107c6_d8ef_11eb_b589_646c80b0af54row0_col2" class="data row0 col2" >780</td>
#                         <td id="T_3fa107c6_d8ef_11eb_b589_646c80b0af54row0_col3" class="data row0 col3" >$2379.77</td>
#             </tr>
#     </tbody></table>

# %%
# Gender Demographics

# Duplicates are droping the SN column
dup_drop_sn=players_df.drop_duplicates(['SN'])

# Grouping based on gender with above series
gender_demo=dup_drop_sn.groupby('Gender')

# Gender count from grouped data
total_count=gender_demo['Gender'].count()

# Calculating total players using the sum function
demo_total=total_count.sum()

# New dataframe created for the gender demographics
gender_demo_df=pd.DataFrame({"Total Count":total_count, 
                             "Percentage of Players":total_count/demo_total})

# Style formatting to get two decimal places with percentage sign
gender_demo_df.style.format({'Percentage of Players': "{0:.2%}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_3fa9938c_d8ef_11eb_bb27_646c80b0af54" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3fa9938c_d8ef_11eb_bb27_646c80b0af54level0_row0" class="row_heading level0 row0" >Female</th>
#                         <td id="T_3fa9938c_d8ef_11eb_bb27_646c80b0af54row0_col0" class="data row0 col0" >81</td>
#                         <td id="T_3fa9938c_d8ef_11eb_bb27_646c80b0af54row0_col1" class="data row0 col1" >14.06%</td>
#             </tr>
#             <tr>
#                         <th id="T_3fa9938c_d8ef_11eb_bb27_646c80b0af54level0_row1" class="row_heading level0 row1" >Male</th>
#                         <td id="T_3fa9938c_d8ef_11eb_bb27_646c80b0af54row1_col0" class="data row1 col0" >484</td>
#                         <td id="T_3fa9938c_d8ef_11eb_bb27_646c80b0af54row1_col1" class="data row1 col1" >84.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_3fa9938c_d8ef_11eb_bb27_646c80b0af54level0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#                         <td id="T_3fa9938c_d8ef_11eb_bb27_646c80b0af54row2_col0" class="data row2 col0" >11</td>
#                         <td id="T_3fa9938c_d8ef_11eb_bb27_646c80b0af54row2_col1" class="data row2 col1" >1.91%</td>
#             </tr>
#     </tbody></table>

# %%
# Calculating purchasing analysis (Gender)

# Copied from the original dataframe
gender_df

# Calculating gender purchase count
purchase_count = gender_df.groupby("Gender")['Purchase ID'].count()

# Calculating total purchase value
tot_purchase_value=gender_df.groupby("Gender")['Price'].sum()

# Calculating average purchase price
avg_purch_price=tot_purchase_value/purchase_count

# Calculating uniq SN count group by Gender
uniq_sn_count=gender_df.groupby('Gender')['SN'].nunique()

# Calculating average total purchase per person
avg_tot_purch_per_person=tot_purchase_value/uniq_sn_count

# Dataframe for the desired tabular output
purchase_df=pd.DataFrame({'Purchase Count':purchase_count,
                         'Average Purchase Price':avg_purch_price,
                          'Total Purchase Value':tot_purchase_value,
                          'Avg Total Purchase Per Person':avg_tot_purch_per_person})

# Style formating the dataframe
purchase_df.style.format({'Average Purchase Price': "${0:.2f}",
                                "Total Purchase Value":"${0:.2f}",
                                "Avg Total Purchase Per Person":"${0:.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_3fafae4b_d8ef_11eb_9adc_646c80b0af54" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Avg Total Purchase Per Person</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3fafae4b_d8ef_11eb_9adc_646c80b0af54level0_row0" class="row_heading level0 row0" >Female</th>
#                         <td id="T_3fafae4b_d8ef_11eb_9adc_646c80b0af54row0_col0" class="data row0 col0" >113</td>
#                         <td id="T_3fafae4b_d8ef_11eb_9adc_646c80b0af54row0_col1" class="data row0 col1" >$3.20</td>
#                         <td id="T_3fafae4b_d8ef_11eb_9adc_646c80b0af54row0_col2" class="data row0 col2" >$361.94</td>
#                         <td id="T_3fafae4b_d8ef_11eb_9adc_646c80b0af54row0_col3" class="data row0 col3" >$4.47</td>
#             </tr>
#             <tr>
#                         <th id="T_3fafae4b_d8ef_11eb_9adc_646c80b0af54level0_row1" class="row_heading level0 row1" >Male</th>
#                         <td id="T_3fafae4b_d8ef_11eb_9adc_646c80b0af54row1_col0" class="data row1 col0" >652</td>
#                         <td id="T_3fafae4b_d8ef_11eb_9adc_646c80b0af54row1_col1" class="data row1 col1" >$3.02</td>
#                         <td id="T_3fafae4b_d8ef_11eb_9adc_646c80b0af54row1_col2" class="data row1 col2" >$1967.64</td>
#                         <td id="T_3fafae4b_d8ef_11eb_9adc_646c80b0af54row1_col3" class="data row1 col3" >$4.07</td>
#             </tr>
#             <tr>
#                         <th id="T_3fafae4b_d8ef_11eb_9adc_646c80b0af54level0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#                         <td id="T_3fafae4b_d8ef_11eb_9adc_646c80b0af54row2_col0" class="data row2 col0" >15</td>
#                         <td id="T_3fafae4b_d8ef_11eb_9adc_646c80b0af54row2_col1" class="data row2 col1" >$3.35</td>
#                         <td id="T_3fafae4b_d8ef_11eb_9adc_646c80b0af54row2_col2" class="data row2 col2" >$50.19</td>
#                         <td id="T_3fafae4b_d8ef_11eb_9adc_646c80b0af54row2_col3" class="data row2 col3" >$4.56</td>
#             </tr>
#     </tbody></table>

# %%
# Calculating age Demographics of players

# Bins/buckets for groupig data
bins=[0,9,14,19,24,29,34,39,100]

# Labels in accordance with the bin values
age_group=['<10','10-14','15-19','20-24','25-29','30-34','35-39','40+']

# pd.cut is used to cut data with bin values
players_df['Age Ranges']=pd.cut(players_df.Age, bins, labels=age_group)

# Data cleaning based "SN" values
age_demo=players_df.drop_duplicates(['SN'])

# Values sorted based on Age and then grouping by age ranges and count functions
age_demographics_df=age_demo.sort_values('Age').groupby('Age Ranges').count() 

# A new dataframe is created for the age demographics
age_demographics_df=pd.DataFrame({"Count":(age_demographics_df.Age), 
                                  'Percentage of Players':(age_demographics_df.Age/576)})

# Style formatting into percentage
age_demographics_df.style.format({'Percentage of Players': "{0:.2%}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr>    <tr>        <th class="index_name level0" >Age Ranges</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54row0_col0" class="data row0 col0" >17</td>
#                         <td id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54row0_col1" class="data row0 col1" >2.95%</td>
#             </tr>
#             <tr>
#                         <th id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54level0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54row1_col0" class="data row1 col0" >22</td>
#                         <td id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54row1_col1" class="data row1 col1" >3.82%</td>
#             </tr>
#             <tr>
#                         <th id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54level0_row2" class="row_heading level0 row2" >15-19</th>
#                         <td id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54row2_col0" class="data row2 col0" >107</td>
#                         <td id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54row2_col1" class="data row2 col1" >18.58%</td>
#             </tr>
#             <tr>
#                         <th id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54level0_row3" class="row_heading level0 row3" >20-24</th>
#                         <td id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54row3_col0" class="data row3 col0" >258</td>
#                         <td id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54row3_col1" class="data row3 col1" >44.79%</td>
#             </tr>
#             <tr>
#                         <th id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54level0_row4" class="row_heading level0 row4" >25-29</th>
#                         <td id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54row4_col0" class="data row4 col0" >77</td>
#                         <td id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54row4_col1" class="data row4 col1" >13.37%</td>
#             </tr>
#             <tr>
#                         <th id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54level0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54row5_col0" class="data row5 col0" >52</td>
#                         <td id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54row5_col1" class="data row5 col1" >9.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54level0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54row6_col0" class="data row6 col0" >31</td>
#                         <td id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54row6_col1" class="data row6 col1" >5.38%</td>
#             </tr>
#             <tr>
#                         <th id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54level0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54row7_col0" class="data row7 col0" >12</td>
#                         <td id="T_8b2b24bf_d8f0_11eb_9418_646c80b0af54row7_col1" class="data row7 col1" >2.08%</td>
#             </tr>
#     </tbody></table>

# %%
# Calculating purchasing analysis by age

# Above Dataframe players_df is copied to get the bin cut effect.
purchase_age_analysis_df=players_df.copy()

# Sorting dataframe by Age and grouping by Age Ranges
age_ranges=purchase_age_analysis_df.sort_values('Age').groupby('Age Ranges').count()

# Calculating purchase count with age
purchase_count=age_ranges.Age

# Calculating average purchase price 
pur_analysis=purchase_age_analysis_df.sort_values('Age').groupby('Age Ranges')
avg_purchase_price=pur_analysis.Price.mean()

# Calculating total purchase price
tot_purchase_price=pur_analysis.Price.sum()

# Average total purchase per person
# Droping duplicates of column SN and sorting and grouping to get the count
tot_uniq_person=purchase_age_analysis_df.drop_duplicates(['SN'])

# Value sorting and grouping
uniq_person_grp=tot_uniq_person.sort_values('Age').groupby('Age Ranges')

# Finding the the count in ranges based on 'Purchase ID'
range_person_count=uniq_person_grp['Purchase ID'].count()

# Finding the average purchase per person
avg_purchase_per_person=tot_purchase_price/range_person_count

# Purchase analysis(age) dataframe
purchase_analysis=pd.DataFrame({"Purchase Count":purchase_count,
                                "Average Purchase Price":avg_purchase_price,
                                "Total Purchase Value":tot_purchase_price,
                                "Avg Total Purchase Per Person":avg_purchase_per_person})

# Style formating the dataframe
purchase_analysis.style.format({'Average Purchase Price': "${0:.2f}",
                                "Total Purchase Value":"${0:.2f}",
                                "Avg Total Purchase Per Person":"${0:.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_0b309526_d8f1_11eb_b53d_646c80b0af54" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Avg Total Purchase Per Person</th>    </tr>    <tr>        <th class="index_name level0" >Age Ranges</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0b309526_d8f1_11eb_b53d_646c80b0af54level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row0_col0" class="data row0 col0" >23</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row0_col1" class="data row0 col1" >$3.35</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row0_col2" class="data row0 col2" >$77.13</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row0_col3" class="data row0 col3" >$4.54</td>
#             </tr>
#             <tr>
#                         <th id="T_0b309526_d8f1_11eb_b53d_646c80b0af54level0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row1_col0" class="data row1 col0" >28</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row1_col1" class="data row1 col1" >$2.96</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row1_col2" class="data row1 col2" >$82.78</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row1_col3" class="data row1 col3" >$3.76</td>
#             </tr>
#             <tr>
#                         <th id="T_0b309526_d8f1_11eb_b53d_646c80b0af54level0_row2" class="row_heading level0 row2" >15-19</th>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row2_col0" class="data row2 col0" >136</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row2_col1" class="data row2 col1" >$3.04</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row2_col2" class="data row2 col2" >$412.89</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row2_col3" class="data row2 col3" >$3.86</td>
#             </tr>
#             <tr>
#                         <th id="T_0b309526_d8f1_11eb_b53d_646c80b0af54level0_row3" class="row_heading level0 row3" >20-24</th>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row3_col0" class="data row3 col0" >365</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row3_col1" class="data row3 col1" >$3.05</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row3_col2" class="data row3 col2" >$1114.06</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row3_col3" class="data row3 col3" >$4.32</td>
#             </tr>
#             <tr>
#                         <th id="T_0b309526_d8f1_11eb_b53d_646c80b0af54level0_row4" class="row_heading level0 row4" >25-29</th>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row4_col0" class="data row4 col0" >101</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row4_col1" class="data row4 col1" >$2.90</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row4_col2" class="data row4 col2" >$293.00</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row4_col3" class="data row4 col3" >$3.81</td>
#             </tr>
#             <tr>
#                         <th id="T_0b309526_d8f1_11eb_b53d_646c80b0af54level0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row5_col0" class="data row5 col0" >73</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row5_col1" class="data row5 col1" >$2.93</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row5_col2" class="data row5 col2" >$214.00</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row5_col3" class="data row5 col3" >$4.12</td>
#             </tr>
#             <tr>
#                         <th id="T_0b309526_d8f1_11eb_b53d_646c80b0af54level0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row6_col0" class="data row6 col0" >41</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row6_col1" class="data row6 col1" >$3.60</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row6_col2" class="data row6 col2" >$147.67</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row6_col3" class="data row6 col3" >$4.76</td>
#             </tr>
#             <tr>
#                         <th id="T_0b309526_d8f1_11eb_b53d_646c80b0af54level0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row7_col0" class="data row7 col0" >13</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row7_col1" class="data row7 col1" >$2.94</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row7_col2" class="data row7 col2" >$38.24</td>
#                         <td id="T_0b309526_d8f1_11eb_b53d_646c80b0af54row7_col3" class="data row7 col3" >$3.19</td>
#             </tr>
#     </tbody></table>

# %%
# Calculating top spenders

# Grouping based on column SN
group_sn = players_df.groupby('SN')

# Calculating the sum of Price
p_value=group_sn.Price.sum()

# Purchase count of top spenders
p_count=group_sn['Item ID'].count()

# Top spenders datafram
top_spenders=pd.DataFrame({"Purchase Count":p_count,
                           "Average Purchase Price":p_value/p_count,
                           "Total Purchase Value":p_value})

# Style formatting the dataframe in the descending order of Total Purchase Value
top_spenders.sort_values(by=['Total Purchase Value'],ascending=False
                        ).head().style.format({'Average Purchase Price': "${0:.2f}",
                                               "Total Purchase Value":"${0:.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_0c3b193a_d8f1_11eb_a778_646c80b0af54" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >SN</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0c3b193a_d8f1_11eb_a778_646c80b0af54level0_row0" class="row_heading level0 row0" >Lisosia93</th>
#                         <td id="T_0c3b193a_d8f1_11eb_a778_646c80b0af54row0_col0" class="data row0 col0" >5</td>
#                         <td id="T_0c3b193a_d8f1_11eb_a778_646c80b0af54row0_col1" class="data row0 col1" >$3.79</td>
#                         <td id="T_0c3b193a_d8f1_11eb_a778_646c80b0af54row0_col2" class="data row0 col2" >$18.96</td>
#             </tr>
#             <tr>
#                         <th id="T_0c3b193a_d8f1_11eb_a778_646c80b0af54level0_row1" class="row_heading level0 row1" >Idastidru52</th>
#                         <td id="T_0c3b193a_d8f1_11eb_a778_646c80b0af54row1_col0" class="data row1 col0" >4</td>
#                         <td id="T_0c3b193a_d8f1_11eb_a778_646c80b0af54row1_col1" class="data row1 col1" >$3.86</td>
#                         <td id="T_0c3b193a_d8f1_11eb_a778_646c80b0af54row1_col2" class="data row1 col2" >$15.45</td>
#             </tr>
#             <tr>
#                         <th id="T_0c3b193a_d8f1_11eb_a778_646c80b0af54level0_row2" class="row_heading level0 row2" >Chamjask73</th>
#                         <td id="T_0c3b193a_d8f1_11eb_a778_646c80b0af54row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_0c3b193a_d8f1_11eb_a778_646c80b0af54row2_col1" class="data row2 col1" >$4.61</td>
#                         <td id="T_0c3b193a_d8f1_11eb_a778_646c80b0af54row2_col2" class="data row2 col2" >$13.83</td>
#             </tr>
#             <tr>
#                         <th id="T_0c3b193a_d8f1_11eb_a778_646c80b0af54level0_row3" class="row_heading level0 row3" >Iral74</th>
#                         <td id="T_0c3b193a_d8f1_11eb_a778_646c80b0af54row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_0c3b193a_d8f1_11eb_a778_646c80b0af54row3_col1" class="data row3 col1" >$3.40</td>
#                         <td id="T_0c3b193a_d8f1_11eb_a778_646c80b0af54row3_col2" class="data row3 col2" >$13.62</td>
#             </tr>
#             <tr>
#                         <th id="T_0c3b193a_d8f1_11eb_a778_646c80b0af54level0_row4" class="row_heading level0 row4" >Iskadarya95</th>
#                         <td id="T_0c3b193a_d8f1_11eb_a778_646c80b0af54row4_col0" class="data row4 col0" >3</td>
#                         <td id="T_0c3b193a_d8f1_11eb_a778_646c80b0af54row4_col1" class="data row4 col1" >$4.37</td>
#                         <td id="T_0c3b193a_d8f1_11eb_a778_646c80b0af54row4_col2" class="data row4 col2" >$13.10</td>
#             </tr>
#     </tbody></table>

# %%
# Calculating most popular items

# Retrieve the Item ID, Item Name, and Item Price columns
item_df=players_df[['Item ID', 'Item Name', 'Price']]

# Group by Item ID and Item Name
item_group=item_df.groupby(['Item ID', 'Item Name'])

# purchase count calculated by Item ID
phs_count=item_group['Item ID'].count()

# purchase sum calculated by Price
phs_value=item_group['Price'].sum()

# Most popular items dataframe
most_pop_items=pd.DataFrame({"Purchase Count":phs_count,
                             "Item Price":round(phs_value/phs_count,2),
                             "Total Purchase Value":phs_value})

# Rearranging dataframe based on purchase count and style formatting to get two decimal places with $ sign
most_pop_items.sort_values(by=['Purchase Count'],ascending=False
                          ).head().style.format({'Item Price': "${0:.2f}",
                                                 "Total Purchase Value":"${0:.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_520516ec_d8ef_11eb_9a66_646c80b0af54" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T